# %% [markdown]
# <h1>M902 - Project 2</h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# <h2>Question 3</h2>

# %%
t = np.arange(-5.001,5,0.001)

# %%
A1 = 1
f1 = 1
phase1 = 0

s1 = A1*np.cos( 2*np.pi*f1*t + phase1 ) 


A2 = 2
f2 = 3
phase2 = 0

s2 = A2*np.cos( 2*np.pi*f2*t + phase2 ) 


A3 = 1.5
f3 = 2
phase3 = np.pi

s3 = A3*np.cos( 2*np.pi*f3*t + phase3 ) 


A4 = 2
f4 = 0.5
phase4 = 0

s4 = A4*np.cos( 2*np.pi*f4*t + phase4 ) 

steps_to_plot = 5
print(len(s4))

fig, plots = plt.subplots(4,1,figsize=(15,10), sharex=True)
fig.text(0.09,0.5, r"$\bf{y - axis}$", ha="center", va="center", rotation=90)
plt.xlabel(r"$\bf{x - axis}$")

plots[0].grid(True)
plots[0].set_xlim(-2.5,2.5)
plots[0].set_ylim(-2.5,2.5)
plots[0].title.set_text(r"$\bf{y_1 = cos(\ 2πx\ ) }$")
plots[0].plot( t*0, t , "k"  )
plots[0].plot( t/t, t , "k"  )
plots[0].plot( t, s1 , "|"  )

plots[1].grid(True)
plots[1].set_ylim(-2.5,2.5)
plots[1].title.set_text(r"$\bf{y_2 = 2\ cos(\ 6πx\ )  }$")
plots[1].plot( t*0, t , "k"  )
plots[1].plot( t/t, t , "k"  )
plots[1].plot( t, s2 )
plots[1].plot( t, s2 )
plots[1].plot( t, s2 )
plots[1].plot( t, s2, "|" )

plots[2].grid(True)
plots[2].set_ylim(-2.5,2.5)
plots[2].title.set_text(r"$\bf{ y_3 = 1.5\ cos(\ 4πx +\ π\ ) }$")
plots[2].plot( t*0, t , "k"  )
plots[2].plot( t/t, t , "k"  )
plots[2].plot( t, s3 )
plots[2].plot( t, s3 )
plots[2].plot( t, s3, "|"  )

plots[3].grid(True)
plots[3].set_ylim(-2.5,2.5)
plots[3].title.set_text(r"$\bf{ y_4 = 2\ cos(\ πx\ ) }$")
plots[3].plot( t*0, t , "k"  )
plots[3].plot( t/t, t , "k"  )
plots[3].plot( t, s4 )
plots[3].plot( t, s4 )
plots[3].plot( t, s4 )
plots[3].plot( t, s4 )
plots[3].plot( t, s4 , "|" )


fig.suptitle(r"$\bf{ y=A\ cos (2πx\ +\ θ) }$")
# Out:
# 10002
# Text(0.5, 0.98, '$\\bf{ y=A\\ cos (2πx\\ +\\ θ) }$')

# %% [markdown]
# <h2>Question 4</h2>

# %%
x = np.arange(-16.001,16,0.001)
x_inv = np.arange(0.001,16,0.001)

# %%
def exp_2(x):
    return 2**(x)

# %%
def f_log(x):
    return math.log2(x)

# %%
fig, f_plot = plt.subplots(1,1,figsize=(15,10), sharex=True)
# fig.text(0.05,0.5, "y", ha="center", va="center", rotation=90)
plt.xlabel(r"$\bf{x - axis}$")
plt.ylabel(r"$\bf{y - axis}$")

f_plot.grid(True)
# f_plot.title.set_text(r"$\bf{s_3$")
f_plot.set_xlim(-4,16)
f_plot.set_ylim(-4,16)

f = [ exp_2(i) for i in x ]
f_inverse = [ f_log(i) for i in x_inv ]
f_xy = x

# plots[:].set_xlim(5)
f_plot.plot( x, x*0, "k")
f_plot.plot( x*0, x, "k" )
f_plot.plot( x, f, "g", label="$f\ (x)=2^x$" )
f_plot.plot( x_inv, f_inverse, "r", label="$f^{\ -1\ }(x)=log_2(x)$" )
f_plot.plot( x, f_xy, label="$x\ =\ y$" )

#points to draw
#f
x_list = [0,1,2,3]
y_list = [ exp_2(x) for x in x_list ]
# print(y_list)

#f inverse
x_inv_list = [1,2,4,8]
y_inv_list = [ int(f_log(x)) for x in x_inv_list ]
# print(y_inv_list)

f_plot.scatter(x_list, y_list, marker="x", label="$f\ \ points$")
f_plot.scatter(x_inv_list, y_inv_list, marker="s", label="$f^{\ -1}\ points$")

for i, txt in enumerate(x_list):
    f_plot.annotate((x_list[i],y_list[i]), (x_list[i], y_list[i]))
    f_plot.annotate((x_inv_list[i],y_inv_list[i]), (x_inv_list[i], y_inv_list[i]))

f_plot.legend()
plt.xticks([i for i in range(-4,16,1)])

plt.title(r"$\bf{Plot\ of\ f(x)\ =\ 2^x,\ f^{-1}(x)\ =\ log_2(x),\ y\ =\ x\ and\ the\ respective\ points }$")
# Out:
# Text(0.5, 1.0, '$\\bf{Plot\\ of\\ f(x)\\ =\\ 2^x,\\ f^{-1}(x)\\ =\\ log_2(x),\\ y\\ =\\ x\\ and\\ the\\ respective\\ points }$')
